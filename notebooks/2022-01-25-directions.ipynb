# %%
import requests
import os

# %%
api_key = os.environ.get("GOOGLE_API_KEY")

# %%
url = f"https://maps.googleapis.com/maps/api/directions/json"

payload={}
headers = {}

params = {
    "origin": "Rosedale, Toronto, ON",
    "destination": "Union Station Toronto ON",
    "key": api_key,
    "departure_time": "now",
    "mode": "transit",
    "avoid": "tolls|ferries|indoor"
}

response = requests.request("GET", url, headers=headers, params=params)

print(response.text)
# Out:
# {
#    "geocoded_waypoints" : [
#       {
#          "geocoder_status" : "OK",
#          "place_id" : "ChIJHW2KcazM1IkRGJa28C7Z2ug",
#          "types" : [ "neighborhood", "political" ]
#       },
#       {
#          "geocoder_status" : "OK",
#          "place_id" : "ChIJtarowyzL1IkRD8-O294ooGI",
#          "types" : [
#             "establishment",
#             "light_rail_station",
#             "point_of_interest",
#             "transit_station"
#          ]
#       }
#    ],
#    "routes" : [
#       {
#          "bounds" : {
#             "northeast" : {
#                "lat" : 43.683375,
#                "lng" : -79.3738426
#             },
#             "southwest" : {
#                "lat" : 43.6452213,
#                "lng" : -79.3890346
#             }
#          },
#          "copyrights" : "Map data ©2022 Google",
#          "legs" : [
#             {
#                "arrival_time" : {
#                   "text" : "7:30pm",
#                   "time_zone" : "America/Toronto",
#                   "value" : 1643157021
#                },
#                "departure_time" : {
#                   "text" : "7:08pm",
#                   "time_zone" : "America/Toronto",
#                   "value" : 1643155694
#                },
#                "distance" : {
#                   "text" : "6.0 km",
#                   "value" : 5988
#                },
#                "duration" : {
#                   "text" : "22 mins",
#                   "value" : 1327
#                },
#                "end_address" : "Union Station, Toronto, ON M5J 1E6, Canada",
#                "end_location" : {
#                   "lat" : 43.6457338,
#                   "lng" : -79.3791932
#                },
#                "start_address" : "Rosedale, Toronto, ON, Canada",
#                "start_location" : {
#                   "lat" : 43.683375,
#                   "lng" : -79.377172
#                },
#                "steps" : [
#                   {
#                      "distance" : {
#                         "text" : "39 m",
#                         "value" : 39
#                      },
#                      "duration" : {
#                         "text" : "1 min",
#                         "value" : 32
#                      },
#                      "end_location" : {
#                         "lat" : 43.68326589999999,
#                         "lng" : -79.3776347
#                      },
#                      "html_instructions" : "Walk to Scholfield Ave at Maclennan Ave West Side",
#                      "polyline" : {
#                         "points" : "c|riGhjncNTzA"
#                      },
#                      "start_location" : {
#                         "lat" : 43.683375,
#                         "lng" : -79.377172
#                      },
#                      "steps" : [
#                         {
#                            "distance" : {
#                               "text" : "39 m",
#                               "value" : 39
#                            },
#                            "duration" : {
#                               "text" : "1 min",
#                               "value" : 32
#                            },
#                            "end_location" : {
#                               "lat" : 43.68326589999999,
#                               "lng" : -79.3776347
#                            },
#                            "polyline" : {
#                               "points" : "c|riGhjncNTzA"
#                            },
#                            "start_location" : {
#                               "lat" : 43.683375,
#                               "lng" : -79.377172
#                            },
#                            "travel_mode" : "WALKING"
#                         }
#                      ],
#                      "travel_mode" : "WALKING"
#                   },
#                   {
#                      "distance" : {
#                         "text" : "2.1 km",
#                         "value" : 2086
#                      },
#                      "duration" : {
#                         "text" : "5 mins",
#                         "value" : 320
#                      },
#                      "end_location" : {
#                         "lat" : 43.676842,
#                         "lng" : -79.38887799999999
#                      },
#                      "html_instructions" : "Bus towards Rosedale to Rosedale Station",
#                      "polyline" : {
#                         "points" : "o{riGjmncNPK@@DBJDLCHCn@Q^Mn@QTIFADADENQ?@@@@@@??@@??@@?@?@?@?@?@??A@?@?@A@A@A?A@??A@A?C@C?E?GAC?E?M?_@?OAG@_@?G@O@MBO@KBKVgA^sAZiAdA}DH_@ZJ`Cp@zCz@PDNFfBf@fAXJDt@RPF~@X?D?DAPCPAP?NAV?R?L@@?VDj@Dh@BTBVVvBFV@L@J?L?J?F?@YFG@EBGBEBCDGDABCDCFABCHIRKTAFCFCHERALAFAJEh@G`A?BGvAKbB?DAJANAHCNCHGPABCFMd@ABIXELIZ?BADAHAJCR?T?XBr@@Z@P@XD`@?F@@@FDTJd@BJL`@JTDHJLDHJNFJDLDP@B@HN`A@RD^BT@X?ZB`@?J?F?@@D@F@J@HBHDNJ\\Lf@HX@?@F?F@F?B@B?B?B?FANAFAB?BAFAB?FADALAX?J?P?H@N@RD^DZ?@NnAT`BNdA@F@HBNF`@@FHl@j@OAM"
#                      },
#                      "start_location" : {
#                         "lat" : 43.683285,
#                         "lng" : -79.377663
#                      },
#                      "transit_details" : {
#                         "arrival_stop" : {
#                            "location" : {
#                               "lat" : 43.676842,
#                               "lng" : -79.38887799999999
#                            },
#                            "name" : "Rosedale Station"
#                         },
#                         "arrival_time" : {
#                            "text" : "7:14pm",
#                            "time_zone" : "America/Toronto",
#                            "value" : 1643156046
#                         },
#                         "departure_stop" : {
#                            "location" : {
#                               "lat" : 43.683285,
#                               "lng" : -79.377663
#                            },
#                            "name" : "Scholfield Ave at Maclennan Ave West Side"
#                         },
#                         "departure_time" : {
#                            "text" : "7:08pm",
#                            "time_zone" : "America/Toronto",
#                            "value" : 1643155726
#                         },
#                         "headsign" : "Rosedale to Rosedale Station",
#                         "line" : {
#                            "agencies" : [
#                               {
#                                  "name" : "TTC",
#                                  "phone" : "1 (416) 393-4636",
#                                  "url" : "https://www.ttc.ca/"
#                               }
#                            ],
#                            "color" : "#ed3237",
#                            "name" : "Rosedale",
#                            "short_name" : "82",
#                            "text_color" : "#ffffff",
#                            "vehicle" : {
#                               "icon" : "//maps.gstatic.com/mapfiles/transit/iw2/6/bus2.png",
#                               "name" : "Bus",
#                               "type" : "BUS"
#                            }
#                         },
#                         "num_stops" : 9
#                      },
#                      "travel_mode" : "TRANSIT"
#                   },
#                   {
#                      "distance" : {
#                         "text" : "54 m",
#                         "value" : 54
#                      },
#                      "duration" : {
#                         "text" : "1 min",
#                         "value" : 55
#                      },
#                      "end_location" : {
#                         "lat" : 43.676613,
#                         "lng" : -79.388451
#                      },
#                      "html_instructions" : "Walk to Rosedale",
#                      "polyline" : {
#                         "points" : "mtqiGnspcNDAlAsA"
#                      },
#                      "start_location" : {
#                         "lat" : 43.6770268,
#                         "lng" : -79.38888109999999
#                      },
#                      "steps" : [
#                         {
#                            "distance" : {
#                               "text" : "1 m",
#                               "value" : 0
#                            },
#                            "duration" : {
#                               "text" : "1 min",
#                               "value" : 0
#                            },
#                            "end_location" : {
#                               "lat" : 43.6770268,
#                               "lng" : -79.38888109999999
#                            },
#                            "html_instructions" : "Head on \u003cb\u003eCrescent Rd\u003c/b\u003e",
#                            "polyline" : {
#                               "points" : "mtqiGnspcN"
#                            },
#                            "start_location" : {
#                               "lat" : 43.6770268,
#                               "lng" : -79.38888109999999
#                            },
#                            "travel_mode" : "WALKING"
#                         },
#                         {
#                            "distance" : {
#                               "text" : "54 m",
#                               "value" : 54
#                            },
#                            "duration" : {
#                               "text" : "1 min",
#                               "value" : 55
#                            },
#                            "end_location" : {
#                               "lat" : 43.676613,
#                               "lng" : -79.388451
#                            },
#                            "html_instructions" : "Take entrance \u003cspan class=\"location\"\u003eCrescent Road\u003c/span\u003e",
#                            "polyline" : {
#                               "points" : "gtqiGlspcNlAsA"
#                            },
#                            "start_location" : {
#                               "lat" : 43.67700199999999,
#                               "lng" : -79.38887
#                            },
#                            "travel_mode" : "WALKING"
#                         }
#                      ],
#                      "travel_mode" : "WALKING"
#                   },
#                   {
#                      "distance" : {
#                         "text" : "3.8 km",
#                         "value" : 3779
#                      },
#                      "duration" : {
#                         "text" : "10 mins",
#                         "value" : 606
#                      },
#                      "end_location" : {
#                         "lat" : 43.6452213,
#                         "lng" : -79.3806034
#                      },
#                      "html_instructions" : "Subway towards Yonge-University to Vaughan Metropolitan Centre Station",
#                      "polyline" : {
#                         "points" : "yqqiGxppcNBPpE{AvAg@bCy@rBiAlAy@fAa@~C}@`D}@dAYjA]xA_@nA]pZsIz@UhAYxAa@bAOjBQlAGlAJ~@Nd@Jt@Hv@Et@SXIhFaBn@WbDiAnAe@B?xCeA`Bi@jA]lCy@XMrAe@tIkCdImCDAnCu@|Bo@`Cu@zFmBl@Uj@Of@Mf@K\\Gj@Gl@Eh@?l@Dh@Pf@X`@\\X\\Tb@Xl@`@lAZjAVtALfAVnB@FnAi@"
#                      },
#                      "start_location" : {
#                         "lat" : 43.676613,
#                         "lng" : -79.388451
#                      },
#                      "transit_details" : {
#                         "arrival_stop" : {
#                            "location" : {
#                               "lat" : 43.6452213,
#                               "lng" : -79.3806034
#                            },
#                            "name" : "Union Station"
#                         },
#                         "arrival_time" : {
#                            "text" : "7:30pm",
#                            "time_zone" : "America/Toronto",
#                            "value" : 1643157012
#                         },
#                         "departure_stop" : {
#                            "location" : {
#                               "lat" : 43.676613,
#                               "lng" : -79.388451
#                            },
#                            "name" : "Rosedale"
#                         },
#                         "departure_time" : {
#                            "text" : "7:20pm",
#                            "time_zone" : "America/Toronto",
#                            "value" : 1643156406
#                         },
#                         "headsign" : "Yonge-University to Vaughan Metropolitan Centre Station",
#                         "line" : {
#                            "agencies" : [
#                               {
#                                  "name" : "TTC",
#                                  "phone" : "1 (416) 393-4636",
#                                  "url" : "https://www.ttc.ca/"
#                               }
#                            ],
#                            "color" : "#f2bf14",
#                            "name" : "Line 1 Yonge–University",
#                            "short_name" : "1",
#                            "text_color" : "#000000",
#                            "vehicle" : {
#                               "icon" : "//maps.gstatic.com/mapfiles/transit/iw2/6/subway2.png",
#                               "name" : "Subway",
#                               "type" : "SUBWAY"
#                            }
#                         },
#                         "num_stops" : 7
#                      },
#                      "travel_mode" : "TRANSIT"
#                   },
#                   {
#                      "distance" : {
#                         "text" : "30 m",
#                         "value" : 30
#                      },
#                      "duration" : {
#                         "text" : "1 min",
#                         "value" : 9
#                      },
#                      "end_location" : {
#                         "lat" : 43.6457338,
#                         "lng" : -79.3791932
#                      },
#                      "html_instructions" : "Walk to Union Station, Toronto, ON M5J 1E6, Canada",
#                      "polyline" : {
#                         "points" : "}qkiGduncNb@v@"
#                      },
#                      "start_location" : {
#                         "lat" : 43.6459117,
#                         "lng" : -79.3789105
#                      },
#                      "steps" : [
#                         {
#                            "distance" : {
#                               "text" : "30 m",
#                               "value" : 30
#                            },
#                            "duration" : {
#                               "text" : "1 min",
#                               "value" : 9
#                            },
#                            "end_location" : {
#                               "lat" : 43.6457338,
#                               "lng" : -79.3791932
#                            },
#                            "polyline" : {
#                               "points" : "}qkiGduncNb@v@"
#                            },
#                            "start_location" : {
#                               "lat" : 43.6459117,
#                               "lng" : -79.3789105
#                            },
#                            "travel_mode" : "WALKING"
#                         }
#                      ],
#                      "travel_mode" : "WALKING"
#                   }
#                ],
#                "traffic_speed_entry" : [],
#                "via_waypoint" : []
#             }
#          ],
#          "overview_polyline" : {
#             "points" : "c|riGhjncNTzAADRIPHVGtC{@LCTWBD@@H@HCDGBOA_@?wAFu@DWv@{C`BgGH_@ZJ|GlB`@LpFzApA`@?JGdA?z@NbCd@tD@l@YHMDYRg@pAOr@Q~BSdEIt@q@xBMn@Et@FzBHdAVnAXv@PV^r@FTPjALbBBhABVLn@d@~ABZ@RE^EXCdAHlAj@nEVfBHh@Hl@j@OAMe@?rAuABPpE{AzEaBrBiAlAy@fAa@~C}@fFwAdD}@`]qJdCo@xAa@bAOjBQlAGlAJ~@NzATv@Et@SbGkBfHgCzFoBxEwAlBs@tIkCdImCtCw@~FeBtIsCnAYhAOl@Eh@?l@Dh@Pf@X`@\\n@`AXl@`@lAZjAVtAd@vD@FnAi@iCqIb@v@"
#          },
#          "summary" : "",
#          "warnings" : [
#             "Walking directions are in beta. Use caution – This route may be missing sidewalks or pedestrian paths."
#          ],
#          "waypoint_order" : []
#       }
#    ],
#    "status" : "OK"
# }
